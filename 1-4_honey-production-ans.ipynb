# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set()

# %%
# data resource: https://www.kaggle.com/jessicali9530/honey-production
data = "honey-production/datasets_20465_26638_honeyproduction.csv"

# %%
honey = pd.read_csv(data)
honey.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# ## How has honey production yield changed from 1998 to 2012?

# %%
fig = plt.figure(figsize=(12, 9))
ax = plt.gca()
sns.scatterplot(x="year", y="yieldpercol", data=honey, ax=ax)

# %%
fig = plt.figure(figsize=(12, 9))
ax = plt.gca()
sns.boxplot(x="year", y="yieldpercol", data=honey, ax=ax)

# %%
fig = plt.figure(figsize=(12, 9))
ax = plt.gca()
sns.violinplot(x="year", y="yieldpercol", data=honey, ax=ax)

# %%
fig = plt.figure(figsize=(12, 9))
ax = plt.gca()
sns.swarmplot(x="year", y="yieldpercol", data=honey, ax=ax)

# %%
fig = plt.figure(figsize=(12, 9))
ax = plt.gca()
sns.scatterplot(x="year", y="yieldpercol", hue="state", data=honey, ax=ax)

# %% [markdown]
# ## Over time, which states produce the most honey? Which produce the least?

# %%
honey.groupby("year").describe()
# Out:
#      numcol                                                                  \
#       count          mean            std     min      25%      50%      75%
# year
# 1998   43.0  60953.488372   85355.545887  3000.0   9500.0  27000.0  70000.0
# 1999   43.0  61325.581395   88411.570276  3000.0   9500.0  27000.0  67000.0
# 2000   43.0  60558.139535   89099.543670  4000.0  10500.0  25000.0  56500.0
# 2001   44.0  57772.727273   88713.771154  4000.0   9000.0  24500.0  53500.0
# 2002   44.0  58295.454545   91698.844695  3000.0   9000.0  23000.0  52500.0
# 2003   44.0  58886.363636   94420.685531  2000.0   7000.0  24500.0  59750.0
# 2004   41.0  61926.829268   91051.191712  5000.0   9000.0  30000.0  64000.0
# 2005   41.0  58390.243902   88023.257736  5000.0  10000.0  28000.0  59000.0
# 2006   41.0  58000.000000   85182.157756  5000.0  10000.0  28000.0  63000.0
# 2007   41.0  59219.512195   90014.863271  4000.0  10000.0  28000.0  60000.0
# 2008   41.0  56731.707317   87691.226582  4000.0   9000.0  25000.0  58000.0
# 2009   40.0  61800.000000   96563.570133  5000.0   9000.0  25000.0  63500.0
# 2010   40.0  66650.000000  107940.285011  4000.0   9750.0  26500.0  65750.0
# 2011   40.0  61650.000000   97898.311973  4000.0   8000.0  23500.0  66500.0
# 2012   40.0  62725.000000   97974.875770  4000.0   7750.0  25000.0  60500.0
#
#                yieldpercol             ... priceperlb       prodvalue  \
#            max       count       mean  ...        75%   max     count
# year                                   ...
# 1998  450000.0        43.0  69.953488  ...     0.8650  1.65      43.0
# 1999  465000.0        43.0  65.465116  ...     0.8650  1.64      43.0
# 2000  440000.0        43.0  67.581395  ...     0.8650  1.50      43.0
# 2001  460000.0        44.0  64.545455  ...     0.9300  2.14      44.0
# 2002  470000.0        44.0  66.795455  ...     1.4325  2.67      44.0
# 2003  480000.0        44.0  62.545455  ...     1.6150  2.04      44.0
# 2004  390000.0        41.0  64.804878  ...     1.4200  2.10      41.0
# 2005  400000.0        41.0  64.268293  ...     1.2900  3.11      41.0
# 2006  380000.0        41.0  61.853659  ...     1.4000  3.62      41.0
# 2007  420000.0        41.0  59.170732  ...     1.7000  2.99      41.0
# 2008  400000.0        41.0  61.000000  ...     1.6800  2.59      41.0
# 2009  450000.0        40.0  53.850000  ...     2.0125  3.45      40.0
# 2010  510000.0        40.0  56.275000  ...     2.2425  3.32      40.0
# 2011  460000.0        40.0  54.775000  ...     2.3825  4.07      40.0
# 2012  480000.0        40.0  55.175000  ...     2.5475  4.15      40.0
#
#                                                                              \
#               mean           std       min        25%        50%        75%
# year
# 1998  3.397465e+06  5.081114e+06  179000.0   645500.0  1361000.0  3746500.0
# 1999  2.875744e+06  4.068182e+06  186000.0   612500.0  1277000.0  2956000.0
# 2000  3.059721e+06  4.828234e+06  173000.0   580500.0  1035000.0  2559500.0
# 2001  3.006409e+06  4.581726e+06  174000.0   602000.0  1138500.0  2968750.0
# 2002  5.165955e+06  7.788900e+06  259000.0   731750.0  1836000.0  5613000.0
# 2003  5.729068e+06  9.591644e+06  162000.0   754500.0  1906500.0  5086000.0
# 2004  4.812366e+06  6.969411e+06  278000.0   716000.0  1984000.0  5052000.0
# 2005  3.921780e+06  6.091451e+06  345000.0   858000.0  1769000.0  2981000.0
# 2006  3.851805e+06  5.090348e+06  369000.0   785000.0  1826000.0  4554000.0
# 2007  3.935512e+06  5.481904e+06  309000.0   905000.0  1818000.0  4169000.0
# 2008  5.609561e+06  9.390274e+06  381000.0   946000.0  2016000.0  5775000.0
# 2009  5.348000e+06  8.793110e+06  474000.0   843750.0  1834500.0  5726750.0
# 2010  6.959250e+06  1.304975e+07  420000.0  1029000.0  2452000.0  4651250.0
# 2011  6.467200e+06  1.054978e+07  238000.0  1073000.0  2865500.0  5427250.0
# 2012  7.018125e+06  1.150000e+07  325000.0  1070750.0  3116000.0  6150750.0
#
#
#              max
# year
# 1998  23157000.0
# 1999  15797000.0
# 2000  19665000.0
# 2001  19361000.0
# 2002  35040000.0
# 2003  44702000.0
# 2004  31941000.0
# 2005  27946000.0
# 2006  23569000.0
# 2007  29837000.0
# 2008  48960000.0
# 2009  47817000.0
# 2010  69615000.0
# 2011  54542000.0
# 2012  63590000.0
#
# [15 rows x 48 columns]

# %%
honey.groupby("year").agg({"yieldpercol": np.max})
# Out:
#       yieldpercol
# year
# 1998          128
# 1999          114
# 2000          121
# 2001          106
# 2002          136
# 2003          114
# 2004          105
# 2005          131
# 2006           98
# 2007           92
# 2008           98
# 2009          104
# 2010           98
# 2011          115
# 2012          118

# %%
honey.groupby("year").agg({"yieldpercol": np.min})
# Out:
#       yieldpercol
# year
# 1998           26
# 1999           22
# 2000           21
# 2001           20
# 2002           38
# 2003           19
# 2004           27
# 2005           26
# 2006           23
# 2007           26
# 2008           29
# 2009           32
# 2010           27
# 2011           30
# 2012           32

# %%
maxprod = pd.DataFrame()
for (year, sub) in honey.groupby("year"):
    m = sub["yieldpercol"].max()
    sample = sub[sub["yieldpercol"] == m]
    maxprod.append(sample, ignore_index=True)

# %%
maxprod
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Are there any patterns that can be observed between total honey production and value of production every year? How has value of production, which in some sense could be tied to demand, changed every year?
